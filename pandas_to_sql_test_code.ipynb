# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi

import warnings
warnings.filterwarnings('ignore')

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:password@localhost:5432/sector_analysis_performance')

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Set Alpaca API key and secret
alpaca_api_key = os.getenv("alpaca_api_key")
alpaca_secret_key = os.getenv("alpaca_secret_key")

# Create the Alpaca API object
alpaca = tradeapi.REST(
    alpaca_api_key,
    alpaca_secret_key,
    api_version="v2")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/9s/n_g_46w56nsd3vkp8k85y1jw0000gn/T/ipykernel_667/1232450737.py in <module>
#       7     alpaca_api_key,
#       8     alpaca_secret_key,
# ----> 9     api_version="v2")
#
# ~/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/alpaca_trade_api/rest.py in __init__(self, key_id, secret_key, base_url, api_version, oauth, raw_data)
#     156         """
#     157         self._key_id, self._secret_key, self._oauth = get_credentials(
# --> 158             key_id, secret_key, oauth)
#     159         self._base_url: URL = URL(base_url or get_base_url())
#     160         self._api_version = get_api_version(api_version)
#
# ~/opt/anaconda3/envs/pyvizenv/lib/python3.7/site-packages/alpaca_trade_api/common.py in get_credentials(key_id, secret_key, oauth)
#      83     if key_id is None and oauth is None:
#      84         raise ValueError('Key ID must be given to access Alpaca trade API',
# ---> 85                          ' (env: APCA_API_KEY_ID)')
#      86
#      87     secret_key = secret_key or os.environ.get('APCA_API_SECRET_KEY')
#
# ValueError: ('Key ID must be given to access Alpaca trade API', ' (env: APCA_API_KEY_ID)')

# %%
# Set timeframe to ‘1D’
timeframe = "1D"

# %%
# Set start and end datetimes: 5 years.
start_date = pd.Timestamp("2018-02-01", tz="America/New_York").isoformat()
end_date = pd.Timestamp("2022-01-31", tz="America/New_York").isoformat()

# %%
                        
# Set the ticker information
                        
stock_tickers = ["XLE","XLF","XLRE", "XLK", "XLP", "XLB", "XLI", "XLV", "XLU", "XLY", "XLC"]

# %%
                    
# Get 3 year’s worth of historical price data for Microsoft and Coca-Cola
stock_ticker_df = alpaca.get_barset(
    stock_tickers,
    timeframe,
    start=start_date,
    end=end_date,
    limit=1000,
).df
                        
# Display sample data
stock_ticker_df.head(50)
# Out:
#                              XLB                                        XLC  \
#                             open     high      low   close      volume open
# time
# 2018-02-07 00:00:00-05:00    NaN      NaN      NaN     NaN         NaN  NaN
# 2018-02-08 00:00:00-05:00    NaN      NaN      NaN     NaN         NaN  NaN
# 2018-02-09 00:00:00-05:00    NaN      NaN      NaN     NaN         NaN  NaN
# 2018-02-12 00:00:00-05:00  58.88  59.9500  58.7100  59.600   9802061.0  NaN
# 2018-02-13 00:00:00-05:00  59.36  59.7200  59.2200  59.455   6546863.0  NaN
# 2018-02-14 00:00:00-05:00  58.96  60.3700  58.8400  60.250   7487715.0  NaN
# 2018-02-15 00:00:00-05:00  60.68  60.7200  59.9600  60.700   5253495.0  NaN
# 2018-02-16 00:00:00-05:00  60.52  61.0700  60.2100  60.480   7174858.0  NaN
# 2018-02-20 00:00:00-05:00  60.22  60.6639  59.9900  60.200   3700436.0  NaN
# 2018-02-21 00:00:00-05:00  60.26  61.0700  59.9900  60.000   3506569.0  NaN
# 2018-02-22 00:00:00-05:00  60.26  60.9600  60.1800  60.410   4269624.0  NaN
# 2018-02-23 00:00:00-05:00  60.75  61.3100  60.4400  61.300   3127593.0  NaN
# 2018-02-26 00:00:00-05:00  61.55  61.5950  60.9460  61.560   3007165.0  NaN
# 2018-02-27 00:00:00-05:00  61.50  61.5900  60.7100  60.710   5520889.0  NaN
# 2018-02-28 00:00:00-05:00  60.88  60.9400  59.6200  59.620   4916674.0  NaN
# 2018-03-01 00:00:00-05:00  59.60  59.8500  58.5800  59.020   9127095.0  NaN
# 2018-03-02 00:00:00-05:00  58.67  59.1200  58.3650  58.940   7515007.0  NaN
# 2018-03-28 00:00:00-04:00  NaN NaN   NaN    NaN  ...  80.59  81.5700  80.4800
# 2018-03-29 00:00:00-04:00  NaN NaN   NaN    NaN  ...  81.22  81.9900  80.6700
# 2018-04-02 00:00:00-04:00  NaN NaN   NaN    NaN  ...  81.06  81.4800  78.7400
# 2018-04-03 00:00:00-04:00  NaN NaN   NaN    NaN  ...  79.98  80.9100  79.4890
# 2018-04-04 00:00:00-04:00  NaN NaN   NaN    NaN  ...  79.79  82.1400  79.7900
# 2018-04-05 00:00:00-04:00  NaN NaN   NaN    NaN  ...  82.20  82.2700  81.5400
# 2018-04-06 00:00:00-04:00  NaN NaN   NaN    NaN  ...  81.17  81.5700  79.1600
# 2018-04-09 00:00:00-04:00  NaN NaN   NaN    NaN  ...  80.31  81.7900  80.0800
# 2018-04-10 00:00:00-04:00  NaN NaN   NaN    NaN  ...  81.47  82.3500  81.1950
# 2018-04-11 00:00:00-04:00  NaN NaN   NaN    NaN  ...  81.42  81.9100  81.2500
# 2018-04-12 00:00:00-04:00  NaN NaN   NaN    NaN  ...  81.80  82.3000  81.7400
# 2018-04-13 00:00:00-04:00  NaN NaN   NaN    NaN  ...  82.30  82.3700  81.4300
# 2018-04-16 00:00:00-04:00  NaN NaN   NaN    NaN  ...  82.47  82.8200  82.2800
# 2018-04-17 00:00:00-04:00  NaN NaN   NaN    NaN  ...  83.15  83.3400  82.7150
# 2018-04-18 00:00:00-04:00  NaN NaN   NaN    NaN  ...  83.37  83.5150  82.8300
# 2018-04-19 00:00:00-04:00  NaN NaN   NaN    NaN  ...  83.08  83.1600  82.2310
#
#                                                    XLY                      \
#                              close      volume    open      high       low
# time
# 2018-02-07 00:00:00-05:00      NaN         NaN     NaN       NaN       NaN
# 2018-02-08 00:00:00-05:00      NaN         NaN  104.46  104.7300  100.0800
# 2018-02-09 00:00:00-05:00      NaN         NaN  101.14  101.6659   97.1001
# 2018-02-12 00:00:00-05:00  82.8600  12330849.0  101.79  102.7650  100.7453
# 2018-02-13 00:00:00-05:00  82.9200   7730724.0  101.79  102.9700  101.6200
# 2018-02-14 00:00:00-05:00  83.8600   9151964.0  102.24  104.5700  102.1700
# 2018-02-15 00:00:00-05:00  84.8300   8751008.0  105.00  105.3000  103.8700
# 2018-02-16 00:00:00-05:00  85.4000   8527735.0  104.97  105.6300  104.5600
# 2018-02-20 00:00:00-05:00  84.4700   8024381.0  104.51  105.6000  104.0600
# 2018-02-21 00:00:00-05:00  84.1200   8126563.0  104.94  106.0100  104.3300
# 2018-02-22 00:00:00-05:00  83.9900   5726614.0  104.83  105.2499  104.1400
# 2018-02-23 00:00:00-05:00  85.3300   4824509.0  105.05  105.9000  104.5600
# 2018-02-26 00:00:00-05:00  86.4000   5432369.0  106.31  106.7900  106.0500
# 2018-02-27 00:00:00-05:00  85.5100   6360480.0  106.90  106.9000  104.5200
# 2018-02-28 00:00:00-05:00  84.1300   5547864.0  105.10  105.5400  104.0500
# 2018-03-01 00:00:00-05:00  82.8000  11382254.0  104.18  104.6800  101.9200
# 2018-03-02 00:00:00-05:00  83.6500   9970941.0  101.81  103.2250  101.2900
# 2018-03-05 00:00:00-05:00  84.3900   9155352.0  102.67  104.5000  102.4200
# 2018-02-20 00:00:00-05:00  104.47   5475737.0
# 2018-02-21 00:00:00-05:00  104.33   4391624.0
# 2018-02-22 00:00:00-05:00  104.46   4026752.0
# 2018-02-23 00:00:00-05:00  105.89   2666285.0
# 2018-02-26 00:00:00-05:00  106.78   3228850.0
# 2018-02-27 00:00:00-05:00  104.53   5106156.0
# 2018-02-28 00:00:00-05:00  104.06   4956452.0
# 2018-03-01 00:00:00-05:00  102.94   8696798.0
# 2018-03-02 00:00:00-05:00  103.06   6439377.0
# 2018-03-05 00:00:00-05:00  104.27   4494372.0
# 2018-03-06 00:00:00-05:00  105.01   6811112.0
# 2018-03-07 00:00:00-05:00  104.28   3878266.0
# 2018-03-08 00:00:00-05:00  104.62   3487702.0
# 2018-03-09 00:00:00-05:00  106.25   3259623.0
# 2018-03-12 00:00:00-04:00  106.58   3858558.0
# 2018-03-13 00:00:00-04:00  105.85   5029699.0
# 2018-03-14 00:00:00-04:00  105.68   4007379.0
# 2018-03-15 00:00:00-04:00  105.59   3138408.0
# 2018-03-16 00:00:00-04:00  105.17   2990090.0
# 2018-03-19 00:00:00-04:00  103.88   5070506.0
# 2018-03-20 00:00:00-04:00  104.51   2966375.0
# 2018-03-21 00:00:00-04:00  104.41   4718367.0
# 2018-03-22 00:00:00-04:00  102.19   6458756.0
# 2018-03-23 00:00:00-04:00  100.17   7824351.0
# 2018-03-26 00:00:00-04:00  103.14   6151324.0
# 2018-03-27 00:00:00-04:00  101.13   5841143.0
# 2018-03-28 00:00:00-04:00   99.87  12419511.0
# 2018-03-29 00:00:00-04:00  101.30   6754577.0
# 2018-04-02 00:00:00-04:00   98.44  10566509.0
# 2018-04-03 00:00:00-04:00   99.69   6844862.0
# 2018-04-04 00:00:00-04:00  101.51   6946904.0
# 2018-04-05 00:00:00-04:00  102.87   3862552.0
# 2018-04-06 00:00:00-04:00  100.68   8116707.0
# 2018-04-09 00:00:00-04:00  100.45   3951901.0
# 2018-04-10 00:00:00-04:00  101.66   6003702.0
# 2018-04-11 00:00:00-04:00  101.35   4455513.0
# 2018-04-12 00:00:00-04:00  101.78   2716357.0
# 2018-04-13 00:00:00-04:00  101.23   4030613.0
# 2018-04-16 00:00:00-04:00  101.97   3731165.0
# 2018-04-17 00:00:00-04:00  103.86   3601537.0
# 2018-04-18 00:00:00-04:00  104.37   3010821.0
# 2018-04-19 00:00:00-04:00  104.04   3658944.0
#
# [50 rows x 55 columns]

# %%
stock_ticker_close_df = stock_ticker_df.iloc[:, stock_ticker_df.columns.get_level_values(1)=='close']
stock_ticker_close_df.columns = stock_ticker_close_df.columns.droplevel(1)

# %%
len(stock_ticker_close_df)
# Out:
# 1003

# %%
stock_ticker_close_df.isnull().sum()
# Out:
# XLB      3
# XLC     91
# XLE      3
# XLF      3
# XLI      3
# XLK      3
# XLP      3
# XLRE     3
# XLU      3
# XLV      3
# XLY      3
# dtype: int64

# %%
stock_ticker_close_df.dropna(inplace = True)
stock_ticker_close_df.isnull().sum()
# Out:
# XLB     0
# XLC     0
# XLE     0
# XLF     0
# XLI     0
# XLK     0
# XLP     0
# XLRE    0
# XLU     0
# XLV     0
# XLY     0
# dtype: int64

# %%
stock_ticker_close_df.to_sql('stock_ticker_close', engine)
