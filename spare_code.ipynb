# %% [markdown]
# # Aggregate Returns

# %%
bond_returns_agg_mean_daily = bond_returns.mean(axis=1)

# %%
bond_returns_agg_mean_daily
# Out:
# Date
# 2018-02-12    0.001444
# 2018-02-13    0.002050
# 2018-02-14   -0.007073
# 2018-02-15    0.001331
# 2018-02-16    0.002978
#                 ...
# 2022-01-24   -0.003498
# 2022-01-25   -0.001466
# 2022-01-26   -0.008615
# 2022-01-27    0.009272
# 2022-01-28    0.001395
# Length: 998, dtype: float64

# %%
bond_returns_agg_mean_cumulative = (1 + bond_returns_agg_mean_daily).cumprod() - 1
bond_returns_agg_mean_cumulative.hvplot()
# Out:
# :Curve   [Date]   (0)
